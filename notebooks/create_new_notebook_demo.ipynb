# %% [markdown]
# # Creating and Interacting with a Jupyter Notebook in Python
#
# This notebook demonstrates how to programmatically create and interact with a Jupyter notebook using Python. We'll cover importing required libraries, creating a new notebook, adding code cells, and saving the notebook.

# %% [markdown]
# ## 1. Import Required Libraries
#
# First, import the necessary libraries for notebook creation and file handling. We'll use `nbformat` to create and manipulate notebooks, and `os` for file operations.

# %% [markdown]
# ## 2. Create a New Jupyter Notebook File
#
# Use `nbformat` to create a new notebook object and add an initial code cell. This demonstrates how to start building a notebook programmatically.

# %% [markdown]
# ## 3. Add and Run a Simple Python Code Cell
#
# Now, let's add a code cell with a simple Python statement. In a Jupyter interface, you can run the cell by selecting it and pressing Shift+Enter.
