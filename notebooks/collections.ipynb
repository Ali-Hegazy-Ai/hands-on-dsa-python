# %%
import collections as collections
print("Python’s collections module provides alternatives to built-in types that can be more efficient\n and easier to use in certain situations. Here are some of the most commonly \n used data structures from thecollections module:")
# Out:
# Python’s collections module provides alternatives to built-in types that can be more efficient
#  and easier to use in certain situations. Here are some of the most commonly
#  used data structures from thecollections module:
